# %%
import os 
import torch
import joblib
import numpy as np
import os.path as osp
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.ensemble import RandomForestRegressor
import heapq
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utils

# %%
torch.set_default_dtype(torch.double)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

config = {
    #'dataset': 'IPIN2020_Track3_5F', #['NTU_CSIE_5F', 'DSI', 'IPIN2016_Tutorial', 'IPIN2020_Track3_2F', 'IPIN2020_Track3_3F', 'IPIN2020_Track3_5F']
    'dataset':'NTUH_2F',
    'method': 'DSAR',#['WKNN', 'RandomForest', 'WiDeep', 'DSAR']
}

def check_format():
    assert config['method'] in ['WKNN', 'RandomForest', 'WiDeep', 'DSAR'], \
        'config method should be [WKNN, RandomForest, WiDeep, DSAR]'
    assert config['dataset'] in ['NTUH_2F','NTU_CSIE_5F', 'DSI', 'IPIN2016_Tutorial', 'IPIN2020_Track3_2F', 'IPIN2020_Track3_3F', 'IPIN2020_Track3_5F'], \
        'config dataset should be [NTU_CSIE_5F, DSI, IPIN2016_Tutorial, IPIN2020_Track3_2F, IPIN2020_Track3_3F, IPIN2020_Track3_5F]'



def load(dataset):
    dir_path = osp.join(os.getcwd(), 'Dataset', dataset)

    training_wifi_pos = np.load(osp.join(dir_path, 'training_wifi_pos.npy'))
    testing_wifi_pos = np.load(osp.join(dir_path, 'testing_wifi_pos.npy'))

    return training_wifi_pos, testing_wifi_pos



def normalize_rssi(rssi):
    return (rssi + 100) / 100



def normalize_pos(pos, boundary):
    max_x, min_x, max_y, min_y = boundary
    norm_pos = np.zeros_like(pos)
    norm_pos[:,0] = (pos[:,0] - min_x) / (max_x - min_x)
    norm_pos[:,1] = (pos[:,1] - min_y) / (max_y - min_y)
    return norm_pos



def restore_pos(norm_pos, boundary):
    max_x, min_x, max_y, min_y = boundary
    pos = np.zeros_like(norm_pos)
    pos[:,0] = norm_pos[:,0] * (max_x - min_x) + min_x
    pos[:,1] = norm_pos[:,1] * (max_y - min_y) + min_y
    return pos



def get_rps(training_wifi_pos):

    rps = {}
    for i in range(training_wifi_pos.shape[0]):
        pos = tuple(training_wifi_pos[i,-2:])
        if pos not in rps:
            rps[pos] = training_wifi_pos[None,i,:-2]
        else:
            rps[pos] = np.r_[rps[pos], training_wifi_pos[None,i,:-2]]
    return rps
        


def add_noise(rssi):
    noisy_rssi = rssi + torch.normal(0, 0.1, rssi.shape)
    noisy_rssi = torch.clip(noisy_rssi, 0, 1)
    mask = torch.rand(rssi.shape) < 0.1
    noisy_rssi[mask] = 0
    return noisy_rssi
    


def get_boundary(training_pos, testing_pos):
    max_x = max(training_pos[:,0].max(), testing_pos[:,0].max())
    min_x = min(training_pos[:,0].min(), testing_pos[:,0].min())
    max_y = max(training_pos[:,1].max(), testing_pos[:,1].max())
    min_y = min(training_pos[:,1].min(), testing_pos[:,1].min())
    
    return (max_x, min_x, max_y, min_y)



def RBF(origin, reconstruction, gamma=16, axis=None):
    return np.e**(-gamma * np.linalg.norm(origin - reconstruction, axis=axis)**2)



def plot_wifi_pos(dataset, method, training_pos, testing_pos, pred_pos, pred_err):

    dir_path = osp.join(os.getcwd(), 'Result', dataset, method)

    fig, (axs0, axs1, axs2) = plt.subplots(1, 3, figsize=(20, 5), sharex=True, sharey=True)

    axs0.plot(training_pos[:,0], training_pos[:,1], 'ob')
    axs0.set_title('Training Points')
    axs0.grid()

    axs1.plot(testing_pos[:,0], testing_pos[:,1], 'og')
    axs1.set_title('Testing Points')
    axs1.grid()

    axs2.plot(pred_pos[:,0], pred_pos[:,1], 'or')
    axs2.set_title('Prediction Points')
    axs2.grid()

    fig.tight_layout()
    plt.savefig(osp.join(dir_path, dataset), bbox_inches='tight')
    np.save(osp.join(dir_path, 'loc_err.npy'), pred_err)
    np.save(osp.join(dir_path, 'pred_pos.npy'), pred_pos)
    
    
def plot_loss(r_losses, reg_losses, v_losses):
    x = [i for i in range(len(r_losses))]
    
    plt.plot(x, r_losses , label = "rec loss")
    plt.plot(x, reg_losses, label = "reg loss")
    plt.plot(x, v_losses, label = "val loss")
    plt.legend()
    plt.show()


def DSAR_testing(query_wifi_pos, dataset, boundary):

    dir_path = osp.join(os.getcwd(), 'Result', dataset, 'DSAR')
    inputs = normalize_rssi(query_wifi_pos[:,:-2])
    labels = query_wifi_pos[:,-2:]

    path = osp.join(dir_path, 'dsar.pth') 
    network = torch.load(path).to(device) # if u don't have gpu, add map_location='cpu' in load's parameter
    network.eval()

    with torch.no_grad():
        inputs = torch.from_numpy(inputs).to(device)
        rssi_reconst, pos = network(inputs)
        rssi_reconst = rssi_reconst.cpu().numpy()
        pred_pos = restore_pos(pos.cpu().numpy(), boundary)
        loc_err = np.linalg.norm(pred_pos - labels, axis=1)

    return pred_pos, loc_err, rssi_reconst

# %% [markdown]
# ## Model

# %%
import torch.nn as nn

class DenoisingAutoEncoder(nn.Module):
    def __init__(self, input_size):
        super(DenoisingAutoEncoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_size, 512),
            nn.Sigmoid(),
            nn.Linear(512, 1024),
            nn.Sigmoid(),
            nn.Linear(1024, 2048),
            nn.Sigmoid(),
        )

        self.decoder = nn.Sequential(
            nn.Linear(2048, 1024),
            nn.Sigmoid(),
            nn.Linear(1024, 512),
            nn.Sigmoid(),
            nn.Linear(512, input_size),
            nn.Sigmoid(),
        )

        for m in self.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('sigmoid')) 

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


class AutoRegression(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(AutoRegression, self).__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.Sigmoid(),
            nn.Linear(256, 128),
            nn.Sigmoid(),
            nn.Linear(128, hidden_size),
            nn.Sigmoid(),
        )

        self.decoder = nn.Sequential(
            nn.Linear(hidden_size, 128),
            nn.Sigmoid(),
            nn.Linear(128, 256),
            nn.Sigmoid(),
            nn.Linear(256, input_size),
            nn.Sigmoid()
        )

        self.regression = nn.Sequential(
            nn.Linear(hidden_size, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 8),
            nn.ReLU(),
            nn.Linear(8, 4),
            nn.ReLU(),
            nn.Linear(4, 2),
        )


        for m in self.encoder.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('sigmoid'))
        for m in self.decoder.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('sigmoid'))

        for m in self.regression.modules():
            if isinstance(m, nn.Linear):
                m.weight.data = nn.init.xavier_uniform_(m.weight.data, gain=nn.init.calculate_gain('relu')) 

    def forward(self, x):
        x = self.encoder(x)
        o1 = self.decoder(x)
        o2 = self.regression(x)
        return (o1, o2)

# %% [markdown]
# ## Training

# %%
class RadioMap(Dataset):
    def __init__(self, inputs, labels):
        self.inputs = torch.from_numpy(inputs)
        self.labels = torch.from_numpy(labels)
        
    def __getitem__(self, index):
        return (self.inputs[index], self.labels[index])
        
    def __len__(self):
        return len(self.labels)
def DSAR_training(dataset, training_wifi_pos, boundary):
    dir_path = osp.join(os.getcwd(), 'Result', dataset, 'DSAR')
    rps = get_rps(training_wifi_pos)

    inputs = normalize_rssi(training_wifi_pos[:,:-2])
    labels = normalize_pos(training_wifi_pos[:,-2:], boundary)
    radio_map = RadioMap(inputs, labels)
    loader = DataLoader(dataset=radio_map, shuffle=True, batch_size=16)
    
    r_losses = []
    reg_losses = []
    V_losses = []

    val_inputs = []
    val_labels = []
    for rp_pos in rps:
        val_inputs.append(np.average(rps[rp_pos], axis=0))
        val_labels.append(np.array(rp_pos, dtype=np.float64))

    val_inputs = normalize_rssi(np.array(val_inputs, dtype=np.float64))
    val_labels = normalize_pos(np.array(val_labels, dtype=np.float64), boundary)
    val_radio_map = RadioMap(val_inputs, val_labels)
    val_loader = DataLoader(dataset=val_radio_map, shuffle=True, batch_size=8)

    epochs = 5000*2
    input_size = training_wifi_pos.shape[1] - 2
    hidden_size = len(rps)

    network = AutoRegression(input_size, hidden_size).to(device)        
    optimizer = torch.optim.Adam(network.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
    criterion = torch.nn.MSELoss()

    best_val_loss = np.inf
    losses = np.zeros((epochs,3), dtype=np.float64)

    network.train()
    for epoch in range(epochs):
        reconst_losses = 0.0
        regression_losses = 0.0

        for inputs, labels in loader:

            noisy_inputs = add_noise(inputs).to(device)
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            reconst_rssi, pos = network(noisy_inputs)

            reconst_loss = criterion(inputs, reconst_rssi)
            regression_loss = criterion(labels, pos)

            loss = reconst_loss + regression_loss
            loss.backward()
            optimizer.step()

            reconst_losses += reconst_loss.item()
            regression_losses += regression_loss.item()
        
        losses[epoch,0] = reconst_losses
        losses[epoch,1] = regression_losses

        network.eval()
        val_losses = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                reconst, pos = network(inputs)
                val_losses += (labels - pos).pow(2).sum()
        
        losses[epoch,2] = val_losses

        if val_losses < best_val_loss:
            best_val_loss = val_losses
            torch.save(network, osp.join(dir_path, 'dsar.pth'))
        
        r_losses.append(reconst_losses)
        reg_losses.append(regression_losses)
        V_losses.append(val_losses.item())
       
        print(f'Epoch {epoch}, reconstruction losses: {reconst_losses}, regression losses: {regression_losses}, validation losses: {val_losses}')

    np.save(osp.join(dir_path, 'losses.npy'), losses)
    
    plot_loss(r_losses, reg_losses, V_losses)

# %%
check_format()

dataset, method = config.values()

training_wifi_pos, testing_wifi_pos = load(dataset)

boundary = get_boundary(training_wifi_pos[:, -2:], testing_wifi_pos[:, -2:])

DSAR_training(dataset, training_wifi_pos, boundary)
# Out:
# Epoch 0, reconstruction losses: 1.080807498602469, regression losses: 2.3763563557895173, validation losses: 20.084982340216836
# Epoch 1, reconstruction losses: 0.30619047883758893, regression losses: 1.9307626793140085, validation losses: 19.80584949930288
# Epoch 2, reconstruction losses: 0.09591880289961804, regression losses: 1.8302184243709507, validation losses: 18.28057172668176
# Epoch 3, reconstruction losses: 0.06879483413233556, regression losses: 2.4536094815081424, validation losses: 17.41888302870139
# Epoch 4, reconstruction losses: 0.053697087421019564, regression losses: 1.754971069885295, validation losses: 16.373939135368857
# Epoch 5, reconstruction losses: 0.053483643026164075, regression losses: 1.577003957132329, validation losses: 15.286429869040063
# Epoch 6, reconstruction losses: 0.05721295004032889, regression losses: 1.4011975649234818, validation losses: 13.462349296297965
# Epoch 7, reconstruction losses: 0.05099774569580384, regression losses: 1.2894443161861298, validation losses: 11.966959077663061
# Epoch 8, reconstruction losses: 0.05142137970479604, regression losses: 1.2240808872181659, validation losses: 10.246850502033613
# Epoch 9, reconstruction losses: 0.05065350596720322, regression losses: 1.2066958523313474, validation losses: 8.659552923438774
# Epoch 10, reconstruction losses: 0.05219423757817196, regression losses: 1.0382982558587537, validation losses: 7.645353832508016
# Epoch 11, reconstruction losses: 0.04794302409582248, regression losses: 0.7289008238985523, validation losses: 6.655177413003434
# Epoch 12, reconstruction losses: 0.046517696160935186, regression losses: 0.6397501705411168, validation losses: 6.102406096035779
# Epoch 13, reconstruction losses: 0.05144574922102598, regression losses: 0.8153661399573464, validation losses: 5.642706301417637
# Epoch 14, reconstruction losses: 0.04700927674069785, regression losses: 0.7692923735121634, validation losses: 6.1373812478157745
# Epoch 15, reconstruction losses: 0.04854947701136441, regression losses: 0.5920941980808027, validation losses: 6.274593444944876
# Epoch 16, reconstruction losses: 0.047706752572198315, regression losses: 0.6854196979334799, validation losses: 5.741819232488493
# Epoch 17, reconstruction losses: 0.05053755333246108, regression losses: 0.5689116540167879, validation losses: 6.4455269932963475
# Epoch 18, reconstruction losses: 0.04904098790039372, regression losses: 0.6423916959449545, validation losses: 5.76882005958944
# Epoch 19, reconstruction losses: 0.048069958060202346, regression losses: 0.7212575706901114, validation losses: 5.541891372858074
# Epoch 20, reconstruction losses: 0.04886555750874263, regression losses: 0.5872847307234113, validation losses: 5.71470324596018
# Epoch 21, reconstruction losses: 0.05572938273902262, regression losses: 0.7609756042202893, validation losses: 5.554329472816427
# Epoch 22, reconstruction losses: 0.04862558388960357, regression losses: 0.6568262698101308, validation losses: 6.232412282794229
# Epoch 23, reconstruction losses: 0.046641890246845834, regression losses: 0.6229158210210722, validation losses: 5.534654267035157
# Epoch 24, reconstruction losses: 0.05189433128260951, regression losses: 0.5818536293159967, validation losses: 5.569200590959414
# Epoch 25, reconstruction losses: 0.0484461713341175, regression losses: 0.5919906331397222, validation losses: 5.807626051765246
# Epoch 26, reconstruction losses: 0.047852560580705264, regression losses: 0.5485890120120466, validation losses: 5.53544266332512
# Epoch 27, reconstruction losses: 0.050479224685329574, regression losses: 0.5857360127274338, validation losses: 5.53863353488371
# Epoch 28, reconstruction losses: 0.04962480954530502, regression losses: 0.6797178388930023, validation losses: 5.598474759680618
# Epoch 29, reconstruction losses: 0.04573565665837526, regression losses: 0.6249037705564473, validation losses: 5.749939076813297
# Epoch 30, reconstruction losses: 0.04910719335327422, regression losses: 0.5974329690896285, validation losses: 5.490620366432944
# Epoch 31, reconstruction losses: 0.05214589976733669, regression losses: 0.6155859285690076, validation losses: 5.4896970215479
# Epoch 32, reconstruction losses: 0.04727328445731838, regression losses: 0.5550290427401622, validation losses: 5.546992265020692
# Epoch 33, reconstruction losses: 0.04735033434849406, regression losses: 0.593420130349583, validation losses: 5.493759468520222
# Epoch 34, reconstruction losses: 0.04789820966966231, regression losses: 0.5251215463338087, validation losses: 5.527142093640479
# Epoch 35, reconstruction losses: 0.04988288223758298, regression losses: 0.7532863314185727, validation losses: 5.490104063786539
# Epoch 36, reconstruction losses: 0.05049753294578602, regression losses: 0.6659479468022139, validation losses: 5.771320365089746
# Epoch 37, reconstruction losses: 0.045818100914856386, regression losses: 0.5697982142380252, validation losses: 5.7076747062446
# Epoch 38, reconstruction losses: 0.0529341326864879, regression losses: 0.6851873357786118, validation losses: 5.957654983823934
# Epoch 39, reconstruction losses: 0.053247885515744435, regression losses: 0.6625060522786062, validation losses: 5.415725821866903
# Epoch 40, reconstruction losses: 0.05017717414894017, regression losses: 0.5566443834851151, validation losses: 5.879924150369064
# Epoch 41, reconstruction losses: 0.048965787518133394, regression losses: 0.6196837344127578, validation losses: 5.5545972546282805
# Epoch 42, reconstruction losses: 0.049927095931584994, regression losses: 0.6030067434206725, validation losses: 5.4247342253493
# Epoch 43, reconstruction losses: 0.047567206801233726, regression losses: 0.5993254995770052, validation losses: 5.379329152639803
# Epoch 44, reconstruction losses: 0.04706215193028991, regression losses: 0.5554925897298616, validation losses: 5.586743610582664
# Epoch 45, reconstruction losses: 0.04757709078234438, regression losses: 0.5704578883600929, validation losses: 5.5071196124586965
# Epoch 46, reconstruction losses: 0.048454240728627876, regression losses: 0.5417183284592876, validation losses: 5.534165760424672
# Epoch 47, reconstruction losses: 0.04990298246618353, regression losses: 0.5779306187570484, validation losses: 5.4087067576704655
# Epoch 48, reconstruction losses: 0.04628294962875421, regression losses: 0.5302397247122983, validation losses: 5.3185779891412555
# Epoch 49, reconstruction losses: 0.053267288534196884, regression losses: 0.6208792043935512, validation losses: 5.56691949880132
# Epoch 50, reconstruction losses: 0.04769171908335739, regression losses: 0.5876013396939695, validation losses: 5.421832594542611
# Epoch 51, reconstruction losses: 0.051573730957216464, regression losses: 0.7178350242480027, validation losses: 5.4881496958465945
# Epoch 52, reconstruction losses: 0.047325762580918765, regression losses: 0.5878926366515183, validation losses: 5.336105698771697
# Epoch 53, reconstruction losses: 0.055292921184636204, regression losses: 0.705772522715452, validation losses: 5.475470975582634
# Epoch 54, reconstruction losses: 0.04848090433713426, regression losses: 0.5779982063074959, validation losses: 5.534081376423463
# Epoch 55, reconstruction losses: 0.05461938062420986, regression losses: 0.7295764879413806, validation losses: 5.1919456604944765
# Epoch 56, reconstruction losses: 0.05101224119610939, regression losses: 0.5699958828628646, validation losses: 6.249244991946231
# Epoch 57, reconstruction losses: 0.04796205696655465, regression losses: 0.6244173563472374, validation losses: 5.181061573484784
# Epoch 58, reconstruction losses: 0.04793892537469376, regression losses: 0.6345038413718596, validation losses: 5.361312855951409
# Epoch 59, reconstruction losses: 0.04776395457297458, regression losses: 0.5711470972893328, validation losses: 5.468540533389165
# Epoch 60, reconstruction losses: 0.051555770573796185, regression losses: 0.6219260357366498, validation losses: 5.143692844262996
# Epoch 61, reconstruction losses: 0.04653521839338493, regression losses: 0.6264773275827435, validation losses: 5.474905699558117
# Epoch 62, reconstruction losses: 0.056728299886735514, regression losses: 0.6579393753067819, validation losses: 5.473867493078057
# Epoch 63, reconstruction losses: 0.051897814983984956, regression losses: 0.6422716029733498, validation losses: 5.618063912188967
# Epoch 64, reconstruction losses: 0.049327446827946236, regression losses: 0.6133840946328697, validation losses: 4.971890912258371
# Epoch 65, reconstruction losses: 0.05263053209508531, regression losses: 0.5813428171556079, validation losses: 4.952030361178642
# Epoch 66, reconstruction losses: 0.050623463795827196, regression losses: 0.606348147119922, validation losses: 4.941906355266852
# Epoch 67, reconstruction losses: 0.05357087474836742, regression losses: 0.5752679398598304, validation losses: 5.245505534155111
# Epoch 68, reconstruction losses: 0.05415807851523399, regression losses: 0.6304480423538225, validation losses: 4.800444009751818
# Epoch 69, reconstruction losses: 0.05053591660232856, regression losses: 0.6254569876805156, validation losses: 5.3396930420295945
# Epoch 70, reconstruction losses: 0.04867748704772046, regression losses: 0.49818493984769785, validation losses: 5.438647760067337
# Epoch 71, reconstruction losses: 0.0493027151106392, regression losses: 0.6588142062043901, validation losses: 4.8478753696992225
# Epoch 72, reconstruction losses: 0.04879581693708133, regression losses: 0.5019366672199717, validation losses: 4.526429108205105
# Epoch 73, reconstruction losses: 0.051808011313506944, regression losses: 0.5137710136366611, validation losses: 4.675697001557882
# Epoch 74, reconstruction losses: 0.046319462703112234, regression losses: 0.5054583021954742, validation losses: 4.536968251844426
# Epoch 75, reconstruction losses: 0.050084448964006476, regression losses: 0.5862847719326202, validation losses: 4.3935527744040295
# Epoch 76, reconstruction losses: 0.059052579238276295, regression losses: 0.6705132835887357, validation losses: 4.506753101271354
# Epoch 77, reconstruction losses: 0.04684026201447926, regression losses: 0.5011957217554776, validation losses: 4.284024786376481
# Epoch 78, reconstruction losses: 0.04776799211738343, regression losses: 0.47113334552348834, validation losses: 4.135799808566295
# Epoch 79, reconstruction losses: 0.04952321295866152, regression losses: 0.5522945276689677, validation losses: 4.120577314300495
# Epoch 80, reconstruction losses: 0.047680490173348175, regression losses: 0.5004148582667047, validation losses: 3.81851505065133
# Epoch 81, reconstruction losses: 0.05069172232410568, regression losses: 0.4316392679863111, validation losses: 4.156874021662494
# Epoch 82, reconstruction losses: 0.052728958514870326, regression losses: 0.4223252105816889, validation losses: 3.705617142826637
# Epoch 83, reconstruction losses: 0.049258833312320206, regression losses: 0.41762210822818774, validation losses: 3.5746738277012575
# Epoch 84, reconstruction losses: 0.05700098524121721, regression losses: 0.5164237652565871, validation losses: 3.4878309795322804
# Epoch 85, reconstruction losses: 0.04963779570397929, regression losses: 0.43323819352770315, validation losses: 3.619231563977565
# Epoch 86, reconstruction losses: 0.048885326195918864, regression losses: 0.45076318848809055, validation losses: 3.3199212083780996
# Epoch 87, reconstruction losses: 0.0536904120858561, regression losses: 0.4763100401169976, validation losses: 3.2702257577170304
# Epoch 88, reconstruction losses: 0.04764105527260632, regression losses: 0.4038616959136034, validation losses: 3.513225198137157
# Epoch 89, reconstruction losses: 0.046719407382959474, regression losses: 0.4126285768135499, validation losses: 3.2782309328909465
# Epoch 90, reconstruction losses: 0.05071196005771637, regression losses: 0.4966971631778101, validation losses: 2.9695358624336445
# Epoch 91, reconstruction losses: 0.04763952763250309, regression losses: 0.3838319188404984, validation losses: 3.167304667730645
# Epoch 92, reconstruction losses: 0.04598885829844396, regression losses: 0.39983516757771137, validation losses: 2.892830570982737
# Epoch 93, reconstruction losses: 0.05122366743281027, regression losses: 0.3994359707074956, validation losses: 2.8949406060857648
# Epoch 94, reconstruction losses: 0.0460219932955032, regression losses: 0.3490260266531925, validation losses: 2.9527795146498725
# Epoch 95, reconstruction losses: 0.051943569317147095, regression losses: 0.4668810900331192, validation losses: 3.0127118068535914
# Epoch 96, reconstruction losses: 0.049712210788015174, regression losses: 0.4227866155835308, validation losses: 2.8952775681578524
# Epoch 97, reconstruction losses: 0.04682600277787325, regression losses: 0.35065543054138915, validation losses: 2.966955825626305
# Epoch 98, reconstruction losses: 0.05308817052168855, regression losses: 0.3769831923236047, validation losses: 2.7484385280143764
# Epoch 99, reconstruction losses: 0.05305487698585191, regression losses: 0.4943368740994245, validation losses: 2.6630481273274444
# Epoch 100, reconstruction losses: 0.04942837376722073, regression losses: 0.33597162866037605, validation losses: 2.620949036615583
# Epoch 101, reconstruction losses: 0.0468743218501799, regression losses: 0.4081536637440062, validation losses: 2.753164202699378
# Epoch 102, reconstruction losses: 0.04763988077687494, regression losses: 0.35051750006162874, validation losses: 2.661441441291901
# Epoch 103, reconstruction losses: 0.05086277498859039, regression losses: 0.3825846631848743, validation losses: 2.718623131244376
# Epoch 104, reconstruction losses: 0.049703040948961746, regression losses: 0.42960998670030304, validation losses: 2.8254997544825557
# Epoch 105, reconstruction losses: 0.04813763317202453, regression losses: 0.3892789978061608, validation losses: 2.6339332200490393
# Epoch 106, reconstruction losses: 0.050541898458525324, regression losses: 0.3709661456290791, validation losses: 2.531576707076993
# Epoch 107, reconstruction losses: 0.05936357414744829, regression losses: 0.4643384161954291, validation losses: 2.5181878467376273
# Epoch 108, reconstruction losses: 0.04805866342591437, regression losses: 0.31222782055357085, validation losses: 2.5931879067214414
# Epoch 109, reconstruction losses: 0.05135485534281523, regression losses: 0.30346582501031844, validation losses: 2.5323698981774383
# Epoch 110, reconstruction losses: 0.050948103179406665, regression losses: 0.502872740905327, validation losses: 2.7780787930346054
# Epoch 111, reconstruction losses: 0.051997714052734276, regression losses: 0.3947478155237157, validation losses: 2.5126461961671382
# Epoch 112, reconstruction losses: 0.04699667235106654, regression losses: 0.34734212376046514, validation losses: 2.8251007546050495
# Epoch 113, reconstruction losses: 0.05270213016964276, regression losses: 0.4311237757815152, validation losses: 3.172484022105457
# Epoch 114, reconstruction losses: 0.04955377499607407, regression losses: 0.40440874083640194, validation losses: 2.4868371612496203
# Epoch 115, reconstruction losses: 0.052223578807409785, regression losses: 0.47899784536959183, validation losses: 2.645841565310934
# Epoch 116, reconstruction losses: 0.05152271749772164, regression losses: 0.4464125290429063, validation losses: 2.5956015340927006
# Epoch 117, reconstruction losses: 0.050878270207145936, regression losses: 0.42734461950599734, validation losses: 2.797317661593193
# Epoch 118, reconstruction losses: 0.04724246397965002, regression losses: 0.34240609617347495, validation losses: 2.5363754199431314
# Epoch 119, reconstruction losses: 0.04760892853223819, regression losses: 0.31164713907425196, validation losses: 2.351607995429892
# Epoch 120, reconstruction losses: 0.05275624936877478, regression losses: 0.43340298892819706, validation losses: 2.26561664366654
# Epoch 121, reconstruction losses: 0.05003121452877155, regression losses: 0.43497223159928905, validation losses: 2.2387448008726505
# Epoch 122, reconstruction losses: 0.05010108816322809, regression losses: 0.4277107659377821, validation losses: 2.253139121335208
# Epoch 123, reconstruction losses: 0.05043739326757918, regression losses: 0.2989841110550216, validation losses: 2.4991289776056815
# Epoch 124, reconstruction losses: 0.05454540636856968, regression losses: 0.32067399985729095, validation losses: 2.1155155516077513
# Epoch 125, reconstruction losses: 0.052769441887452764, regression losses: 0.3134168697348975, validation losses: 2.1613130833520815
# Epoch 126, reconstruction losses: 0.04773732395218045, regression losses: 0.32389100094647005, validation losses: 2.066351289828599
# Epoch 127, reconstruction losses: 0.04925400942014031, regression losses: 0.26573198204311055, validation losses: 1.9614709278472258
# Epoch 128, reconstruction losses: 0.04629638698483484, regression losses: 0.3123336866075827, validation losses: 2.0524730327535257
# Epoch 129, reconstruction losses: 0.04525210555039242, regression losses: 0.29232609547420546, validation losses: 1.8884523068403962
# Epoch 130, reconstruction losses: 0.045859078226503855, regression losses: 0.2682923329787141, validation losses: 1.8273650874870697
# Epoch 131, reconstruction losses: 0.04876105888154978, regression losses: 0.2671872910193347, validation losses: 1.7917138296001016
# Epoch 132, reconstruction losses: 0.04845644263552805, regression losses: 0.27909559481393525, validation losses: 2.1713302585712255
# Epoch 133, reconstruction losses: 0.048472913810890014, regression losses: 0.27038337372894267, validation losses: 1.7494180125852319
# Epoch 134, reconstruction losses: 0.05766130165091017, regression losses: 0.3030360772255816, validation losses: 1.988480134312337
# Epoch 135, reconstruction losses: 0.04733444235540883, regression losses: 0.27632327170389925, validation losses: 1.69437274743748
# Epoch 136, reconstruction losses: 0.05014102726498109, regression losses: 0.3444908485847082, validation losses: 1.731880809756837
# Epoch 137, reconstruction losses: 0.048077676476812, regression losses: 0.2737255481018242, validation losses: 1.7424885032279893
# Epoch 138, reconstruction losses: 0.05088392502149703, regression losses: 0.5504626403399632, validation losses: 1.6150202274216638
# Epoch 139, reconstruction losses: 0.04721998414730468, regression losses: 0.34053540750278294, validation losses: 2.1228384378747895
# Epoch 140, reconstruction losses: 0.054586948661290165, regression losses: 0.34273483562955837, validation losses: 1.9851804168179061
# Epoch 141, reconstruction losses: 0.059660317032338525, regression losses: 0.324041957441601, validation losses: 1.7438814367496862
# Epoch 142, reconstruction losses: 0.05289566900034276, regression losses: 0.4241749724026524, validation losses: 1.4156658285060317
# Epoch 143, reconstruction losses: 0.05140718962974469, regression losses: 0.31027145162277453, validation losses: 1.8702049330190549
# Epoch 144, reconstruction losses: 0.046043573891382826, regression losses: 0.3039050239697683, validation losses: 1.793156689265316
# Epoch 145, reconstruction losses: 0.049585067956441894, regression losses: 0.23466838610442126, validation losses: 1.3649329562114936
# Epoch 146, reconstruction losses: 0.0465965180235367, regression losses: 0.2222933032442841, validation losses: 1.413108686358997
# Epoch 147, reconstruction losses: 0.05074851882494266, regression losses: 0.23888799786874448, validation losses: 1.23751416845088
# Epoch 148, reconstruction losses: 0.04902335522927953, regression losses: 0.21456599326202272, validation losses: 1.1799126496619097
# Epoch 149, reconstruction losses: 0.04851002200363356, regression losses: 0.2393846068489179, validation losses: 1.1716653687590386
# Epoch 150, reconstruction losses: 0.047304198212222814, regression losses: 0.26967077803527173, validation losses: 1.1349104554227003
# Epoch 151, reconstruction losses: 0.04586799607795526, regression losses: 0.16365977932957695, validation losses: 1.3614026470338925
# Epoch 152, reconstruction losses: 0.053307921642017, regression losses: 0.26660973607406335, validation losses: 1.1828085415556422
# Epoch 153, reconstruction losses: 0.05154632450446614, regression losses: 0.2558472125445149, validation losses: 1.1102707467898045
# Epoch 154, reconstruction losses: 0.05083438864553198, regression losses: 0.3550073085128773, validation losses: 1.4691915616110875
# Epoch 155, reconstruction losses: 0.047812479903832944, regression losses: 0.33351225367752135, validation losses: 1.5023555253901906
# Epoch 156, reconstruction losses: 0.04655487692659227, regression losses: 0.2897423833312921, validation losses: 1.2328088329962665
# Epoch 157, reconstruction losses: 0.05247782945490291, regression losses: 0.26016416815348464, validation losses: 1.2130670464323043
# Epoch 158, reconstruction losses: 0.04518894215618451, regression losses: 0.20287684547435197, validation losses: 1.3100031441625697
# Epoch 159, reconstruction losses: 0.04580920717821243, regression losses: 0.18981980420511613, validation losses: 0.8153013564512784
# Epoch 160, reconstruction losses: 0.045366700500970636, regression losses: 0.17541212655755536, validation losses: 0.7465739841729853
# Epoch 161, reconstruction losses: 0.05206805639156986, regression losses: 0.2653833684757868, validation losses: 0.8137381421460177
# Epoch 162, reconstruction losses: 0.048023929819039426, regression losses: 0.20417002071447876, validation losses: 0.7709029938996601
# Epoch 163, reconstruction losses: 0.050928317110022936, regression losses: 0.19281078481492284, validation losses: 0.7856734869034653
# Epoch 164, reconstruction losses: 0.04771157085697654, regression losses: 0.1817861681246041, validation losses: 0.9609941261273516
# Epoch 165, reconstruction losses: 0.05654907786147448, regression losses: 0.2220656871958783, validation losses: 0.6940310594275344
# Epoch 166, reconstruction losses: 0.044393739835606766, regression losses: 0.2090429456203185, validation losses: 0.7437341395561331
# Epoch 167, reconstruction losses: 0.04545599165365706, regression losses: 0.18108768281488352, validation losses: 1.058967647913666
# Epoch 168, reconstruction losses: 0.04523249527349284, regression losses: 0.1661485863384162, validation losses: 0.7130706221369864
# Epoch 169, reconstruction losses: 0.04745268053530871, regression losses: 0.15698865747669277, validation losses: 0.8285977181503912
# Epoch 170, reconstruction losses: 0.04775053196142247, regression losses: 0.13278297919517867, validation losses: 0.6361862974517527
# Epoch 171, reconstruction losses: 0.05032031003024708, regression losses: 0.1689670104115205, validation losses: 0.6043365918096617
# Epoch 172, reconstruction losses: 0.0459901065148981, regression losses: 0.22610088135761108, validation losses: 0.6242886841478895
# Epoch 173, reconstruction losses: 0.04188568602828047, regression losses: 0.3374025405440433, validation losses: 0.6805087538567349
# Epoch 174, reconstruction losses: 0.0435527246728731, regression losses: 0.35282160524437534, validation losses: 1.2765912440128466
# Epoch 175, reconstruction losses: 0.050820759089374376, regression losses: 0.28622865375575457, validation losses: 0.7933677239575999
# Epoch 176, reconstruction losses: 0.04346372996005529, regression losses: 0.20377202975230443, validation losses: 0.6796178713141645
# Epoch 177, reconstruction losses: 0.04627539758703046, regression losses: 0.2587689945792481, validation losses: 0.9612194513730458
# Epoch 178, reconstruction losses: 0.04846087918100768, regression losses: 0.14983945148706285, validation losses: 0.8162182380136452
# Epoch 179, reconstruction losses: 0.04305942347745501, regression losses: 0.1599551441578519, validation losses: 0.6058224932067184
# Epoch 180, reconstruction losses: 0.041740766318097346, regression losses: 0.23598472448598115, validation losses: 0.8475253272318113
# Epoch 181, reconstruction losses: 0.04345212556877272, regression losses: 0.3129597594854481, validation losses: 0.6981082767807922
# Epoch 182, reconstruction losses: 0.04114245246425881, regression losses: 0.16606825853472332, validation losses: 1.0716402753472978
# Epoch 183, reconstruction losses: 0.040807424963607446, regression losses: 0.17576768328499784, validation losses: 0.4935701771926039
# Epoch 184, reconstruction losses: 0.04351905294756779, regression losses: 0.13625008218517318, validation losses: 0.8078227958184435
# Epoch 185, reconstruction losses: 0.04300494366140808, regression losses: 0.23778101806187862, validation losses: 0.7623256088795893
# Epoch 186, reconstruction losses: 0.05173766199659385, regression losses: 0.20797454045311986, validation losses: 0.6581396958608198
# Epoch 187, reconstruction losses: 0.04076554351915218, regression losses: 0.17916547854603404, validation losses: 0.6566335613292543
# Epoch 188, reconstruction losses: 0.04424901827976574, regression losses: 0.17614751404388107, validation losses: 0.8817003092360585
# Epoch 189, reconstruction losses: 0.04182073025528553, regression losses: 0.1417013725846203, validation losses: 0.5216327098384759
# Epoch 190, reconstruction losses: 0.038436180524855236, regression losses: 0.1693732449821281, validation losses: 0.5258134690900489
# Epoch 191, reconstruction losses: 0.04068607351534556, regression losses: 0.22100561482143213, validation losses: 0.6326760177462786
# Epoch 192, reconstruction losses: 0.039465124239390886, regression losses: 0.13027899409648336, validation losses: 0.677623988870891
# Epoch 193, reconstruction losses: 0.03803643687706949, regression losses: 0.17004940525747383, validation losses: 0.6801830884638608
# Epoch 194, reconstruction losses: 0.03670274801522462, regression losses: 0.18434685974128806, validation losses: 0.8301473993670757
# Epoch 195, reconstruction losses: 0.0460143845214366, regression losses: 0.2759418898357904, validation losses: 0.9343976857375881
# Epoch 196, reconstruction losses: 0.03874846859427271, regression losses: 0.17100984848796996, validation losses: 0.6418210470119227
# Epoch 197, reconstruction losses: 0.03957112025680138, regression losses: 0.150984590445386, validation losses: 0.8354083714251314
# Epoch 198, reconstruction losses: 0.041159620026122216, regression losses: 0.19292156615011183, validation losses: 0.5107006345185618
# Epoch 199, reconstruction losses: 0.04164639665566269, regression losses: 0.21756987037818543, validation losses: 0.6068397977276841
# Epoch 200, reconstruction losses: 0.039598116073534695, regression losses: 0.1483635954838331, validation losses: 0.8531498894655976
# Epoch 201, reconstruction losses: 0.0360971583389664, regression losses: 0.14804829056405322, validation losses: 0.8152828748242493
# Epoch 202, reconstruction losses: 0.04234256505491035, regression losses: 0.15335915119805674, validation losses: 0.5548979420584368
# Epoch 203, reconstruction losses: 0.04359067661138038, regression losses: 0.17478333102743127, validation losses: 0.5681622486403861
# Epoch 204, reconstruction losses: 0.03857817186674424, regression losses: 0.1547695606119719, validation losses: 0.651701656622912
# Epoch 205, reconstruction losses: 0.0427063886031034, regression losses: 0.14012862878830207, validation losses: 0.500355726959414
# Epoch 206, reconstruction losses: 0.038451418679281875, regression losses: 0.12701095712526386, validation losses: 0.5346371834564185
# Epoch 207, reconstruction losses: 0.044953318728154765, regression losses: 0.12036981151402867, validation losses: 0.5137036013253576
# Epoch 208, reconstruction losses: 0.03529075505994715, regression losses: 0.12173019431583372, validation losses: 0.5804116978197309
# Epoch 209, reconstruction losses: 0.03477017157882783, regression losses: 0.12859032338635992, validation losses: 0.5404908335868722
# Epoch 210, reconstruction losses: 0.037550967988593836, regression losses: 0.12614336642172932, validation losses: 0.5370280368253799
# Epoch 211, reconstruction losses: 0.03892909330926478, regression losses: 0.17368440815807426, validation losses: 0.7274069770881042
# Epoch 212, reconstruction losses: 0.03952255363164704, regression losses: 0.24226464519320745, validation losses: 0.820272929924542
# Epoch 213, reconstruction losses: 0.03740291103044713, regression losses: 0.19390918619219505, validation losses: 0.7121063689704336
# Epoch 214, reconstruction losses: 0.03725182465015939, regression losses: 0.24240561844591885, validation losses: 0.7392527452388126
# Epoch 215, reconstruction losses: 0.04130237052268288, regression losses: 0.21335443990569403, validation losses: 1.1450744927222356
# Epoch 216, reconstruction losses: 0.03410975902518672, regression losses: 0.1523488078952777, validation losses: 0.5829282039448717
# Epoch 217, reconstruction losses: 0.040232307206476345, regression losses: 0.16131843071242918, validation losses: 0.4936336438813393
# Epoch 218, reconstruction losses: 0.040763017067384597, regression losses: 0.12438582448578736, validation losses: 0.7860311637602048
# Epoch 219, reconstruction losses: 0.03480587157749208, regression losses: 0.12918243681406774, validation losses: 0.5180893571442985
# Epoch 220, reconstruction losses: 0.03552482461039854, regression losses: 0.14795492449618874, validation losses: 0.46704467866327615
# Epoch 221, reconstruction losses: 0.040913910992331354, regression losses: 0.13756901718824455, validation losses: 0.4444226617674748
# Epoch 222, reconstruction losses: 0.03643039188113036, regression losses: 0.14299194802881926, validation losses: 0.5577394888042093
# Epoch 223, reconstruction losses: 0.04260766256360005, regression losses: 0.19197729815367698, validation losses: 0.5196421205369247
# Epoch 224, reconstruction losses: 0.03950838974306108, regression losses: 0.19528166943434172, validation losses: 0.522277057766628
# Epoch 225, reconstruction losses: 0.03384999887309833, regression losses: 0.1476199257021963, validation losses: 1.241666797838845
# Epoch 226, reconstruction losses: 0.03346978242235853, regression losses: 0.1693223457625712, validation losses: 0.5619730721922447
# Epoch 227, reconstruction losses: 0.03769994267613228, regression losses: 0.16172875233193795, validation losses: 0.7281162253233318
# Epoch 228, reconstruction losses: 0.04254154109278534, regression losses: 0.1554753097640118, validation losses: 0.5633453423111285
# Epoch 229, reconstruction losses: 0.03339441593527073, regression losses: 0.14747065790788172, validation losses: 0.41856717810208494
# Epoch 230, reconstruction losses: 0.042904016179091994, regression losses: 0.14267649623604114, validation losses: 0.6014587089353398
# Epoch 231, reconstruction losses: 0.04265187622074436, regression losses: 0.12253911176073697, validation losses: 0.47088408553142447
# Epoch 232, reconstruction losses: 0.03356350833037715, regression losses: 0.13378014146088585, validation losses: 0.5292542773375333
# Epoch 233, reconstruction losses: 0.03952706264349182, regression losses: 0.14093881603373268, validation losses: 0.5771660774284441
# Epoch 234, reconstruction losses: 0.03401480687219492, regression losses: 0.11573225608920049, validation losses: 0.5635940153270067
# Epoch 235, reconstruction losses: 0.03525105917509358, regression losses: 0.12436598730946041, validation losses: 0.4532269718888834
# Epoch 236, reconstruction losses: 0.03605538091035672, regression losses: 0.1573567590380534, validation losses: 0.4689388516940811
# Epoch 237, reconstruction losses: 0.03277766141984855, regression losses: 0.11683074294210831, validation losses: 0.4171442355695287
# Epoch 238, reconstruction losses: 0.03142900526572042, regression losses: 0.10231847472562423, validation losses: 0.6203709894451276
# Epoch 239, reconstruction losses: 0.034507734587468815, regression losses: 0.14002173660551212, validation losses: 0.4655524636618517
# Epoch 240, reconstruction losses: 0.038138335283018285, regression losses: 0.13056702167183845, validation losses: 0.4554898681649887
# Epoch 241, reconstruction losses: 0.03259470002343515, regression losses: 0.1522742840626287, validation losses: 0.5581853508294273
# Epoch 242, reconstruction losses: 0.033335323953895116, regression losses: 0.11457574155210286, validation losses: 0.4426471945164277
# Epoch 243, reconstruction losses: 0.03565661151308138, regression losses: 0.18270887086791626, validation losses: 0.5221935290174594
# Epoch 244, reconstruction losses: 0.03312772699892729, regression losses: 0.12934632329175277, validation losses: 0.6515438916625942
# Epoch 245, reconstruction losses: 0.036940288461139385, regression losses: 0.1685041503754564, validation losses: 0.46284337210937704
# Epoch 246, reconstruction losses: 0.03182234551467729, regression losses: 0.1258704945891458, validation losses: 0.41016519977037447
# Epoch 247, reconstruction losses: 0.03415871449493666, regression losses: 0.13938921751065417, validation losses: 0.4281380659300338
# Epoch 248, reconstruction losses: 0.03177799058623665, regression losses: 0.17084067588321858, validation losses: 0.5187451458734755
# Epoch 249, reconstruction losses: 0.036621807809053705, regression losses: 0.13603254776887633, validation losses: 0.7164397342209645
# Epoch 250, reconstruction losses: 0.03408570702358829, regression losses: 0.17529932467701853, validation losses: 0.5159793304842709
# Epoch 251, reconstruction losses: 0.03508848578978262, regression losses: 0.13750050954107124, validation losses: 0.8294817719680744
# Epoch 252, reconstruction losses: 0.03631889800249996, regression losses: 0.20459317993428566, validation losses: 0.5393069425611995
# Epoch 253, reconstruction losses: 0.033956262401873376, regression losses: 0.11681053504104955, validation losses: 0.5401780001119308
# Epoch 254, reconstruction losses: 0.03839896724005317, regression losses: 0.12461206554071845, validation losses: 0.5144219060000177
# Epoch 255, reconstruction losses: 0.03461439338152223, regression losses: 0.11169593514861573, validation losses: 0.458699885166525
# Epoch 256, reconstruction losses: 0.03586100667139206, regression losses: 0.2104734819611221, validation losses: 0.6146740802392264
# Epoch 257, reconstruction losses: 0.03537839879594761, regression losses: 0.2018294798656338, validation losses: 0.5813160560022514
# Epoch 258, reconstruction losses: 0.033407115890301584, regression losses: 0.17090005361141333, validation losses: 0.49800834004086253
# Epoch 259, reconstruction losses: 0.032776124717931704, regression losses: 0.14255837500613647, validation losses: 0.5914210311601711
# Epoch 260, reconstruction losses: 0.04104339732379811, regression losses: 0.14615768688991332, validation losses: 0.526296688319733
# Epoch 261, reconstruction losses: 0.03283480215321548, regression losses: 0.1635355284133397, validation losses: 0.5259672450006977
# Epoch 262, reconstruction losses: 0.0405112623143579, regression losses: 0.30484949883206147, validation losses: 0.5830445251909302
# Epoch 263, reconstruction losses: 0.031170767509764327, regression losses: 0.1416383036351858, validation losses: 0.6528102951861221
# Epoch 264, reconstruction losses: 0.0392427231101997, regression losses: 0.14902440616930518, validation losses: 0.5245133894931284
# Epoch 265, reconstruction losses: 0.0359837008336483, regression losses: 0.23215341298344735, validation losses: 0.7133122394769237
# Epoch 266, reconstruction losses: 0.03014827651878678, regression losses: 0.14056202907516485, validation losses: 0.8110203983014881
# Epoch 267, reconstruction losses: 0.03422437511421744, regression losses: 0.1849922589956438, validation losses: 0.4635830038179095
# Epoch 268, reconstruction losses: 0.03331979257341806, regression losses: 0.12582693619319654, validation losses: 0.7034057598890432
# Epoch 269, reconstruction losses: 0.034775071074633526, regression losses: 0.13105942803120296, validation losses: 0.5723647201077834
# Epoch 270, reconstruction losses: 0.03301355515859636, regression losses: 0.13463331728865782, validation losses: 0.5010139383172957
# Epoch 271, reconstruction losses: 0.03110750575515884, regression losses: 0.14411307817094418, validation losses: 0.6358709010477565
# Epoch 272, reconstruction losses: 0.03559297911646188, regression losses: 0.1316343350606165, validation losses: 0.6224945938313966
# Epoch 273, reconstruction losses: 0.03229604466573051, regression losses: 0.1519721436729561, validation losses: 0.47256874710562646
# Epoch 274, reconstruction losses: 0.03298051352181319, regression losses: 0.16193309490548954, validation losses: 0.5383784809472527
# Epoch 275, reconstruction losses: 0.032934474015679296, regression losses: 0.12883276105335964, validation losses: 0.6514719840108205
# Epoch 276, reconstruction losses: 0.030815235558394383, regression losses: 0.12585630106739717, validation losses: 0.47613645607055877
# Epoch 277, reconstruction losses: 0.032242685872697234, regression losses: 0.1359857081569499, validation losses: 0.5198421808894121
# Epoch 278, reconstruction losses: 0.036853494129102285, regression losses: 0.14896649759448363, validation losses: 0.610532739817418
# Epoch 279, reconstruction losses: 0.040297006644164704, regression losses: 0.17480007494796812, validation losses: 0.42643665444892176
# Epoch 280, reconstruction losses: 0.03260692611707234, regression losses: 0.15923612675078655, validation losses: 0.5821117876384746
# Epoch 281, reconstruction losses: 0.0337789500810979, regression losses: 0.18073677660401927, validation losses: 0.8159552132011502
# Epoch 282, reconstruction losses: 0.03431208900012782, regression losses: 0.12727095015494458, validation losses: 0.46403918917141207
# Epoch 283, reconstruction losses: 0.03508983073298816, regression losses: 0.13086875944666052, validation losses: 0.5629131237846682
# Epoch 284, reconstruction losses: 0.031066706208954842, regression losses: 0.13164653785179675, validation losses: 0.5802117259775731
# Epoch 285, reconstruction losses: 0.028907701500897196, regression losses: 0.12680390739035238, validation losses: 0.5382269417566775
# Epoch 286, reconstruction losses: 0.03583078793631021, regression losses: 0.19995555992398467, validation losses: 0.5588966431086878
# Epoch 287, reconstruction losses: 0.033351850149760796, regression losses: 0.31065303463342364, validation losses: 0.5874727349721436
# Epoch 288, reconstruction losses: 0.0334973728626566, regression losses: 0.159887264687566, validation losses: 1.3677775711269
# Epoch 289, reconstruction losses: 0.03313050718606551, regression losses: 0.237607082088116, validation losses: 0.8841700382564626
# Epoch 290, reconstruction losses: 0.03464628074030145, regression losses: 0.28658907836304665, validation losses: 0.6099944097469496
# Epoch 291, reconstruction losses: 0.034603957480298, regression losses: 0.15220552433701537, validation losses: 0.5426039820932358
# Epoch 292, reconstruction losses: 0.03197311760772105, regression losses: 0.17620138646498792, validation losses: 0.7735612292189921
# Epoch 293, reconstruction losses: 0.030258971259856427, regression losses: 0.15520128242384124, validation losses: 0.5492327255624168
# Epoch 294, reconstruction losses: 0.02902505514766062, regression losses: 0.11285231902892218, validation losses: 0.5210123493209925
# Epoch 295, reconstruction losses: 0.03383446755483571, regression losses: 0.16418901951523387, validation losses: 0.5356049048322804
# Epoch 296, reconstruction losses: 0.02951777507118671, regression losses: 0.12389612287486379, validation losses: 0.6497712812672222
# Epoch 297, reconstruction losses: 0.03136163294533446, regression losses: 0.11861596788878628, validation losses: 0.5006258837855837
# Epoch 298, reconstruction losses: 0.03017678181250843, regression losses: 0.08774303016257129, validation losses: 0.45889266176315435
# Epoch 299, reconstruction losses: 0.027504781903697713, regression losses: 0.0978068651408477, validation losses: 0.6800935241120015
# Epoch 300, reconstruction losses: 0.03493029312013294, regression losses: 0.1527429761393286, validation losses: 0.5584962359835656
# Epoch 301, reconstruction losses: 0.029269052157343496, regression losses: 0.15572811507418158, validation losses: 0.53198372496745
# Epoch 302, reconstruction losses: 0.03037732585790405, regression losses: 0.18139192350486694, validation losses: 0.7088268823390383
# Epoch 303, reconstruction losses: 0.02714262320197072, regression losses: 0.1267322421809603, validation losses: 0.5436171057761592
# Epoch 304, reconstruction losses: 0.02792609685391147, regression losses: 0.11823172082047827, validation losses: 0.5010207970757097
# Epoch 305, reconstruction losses: 0.028498732571204406, regression losses: 0.1271856718935215, validation losses: 0.5003834512281714
# Epoch 306, reconstruction losses: 0.028650939338997244, regression losses: 0.16760640536077304, validation losses: 0.5068674352697108
# Epoch 307, reconstruction losses: 0.026462529702528024, regression losses: 0.11543681128688024, validation losses: 0.7066056631439676
# Epoch 308, reconstruction losses: 0.03130117764215079, regression losses: 0.14199439655052798, validation losses: 0.45914607021736265
# Epoch 309, reconstruction losses: 0.029124066196728582, regression losses: 0.13252144243936664, validation losses: 0.43791079304953284
# Epoch 310, reconstruction losses: 0.03203932565994955, regression losses: 0.1364405831480748, validation losses: 0.7056681037053589
# Epoch 311, reconstruction losses: 0.028391975568886018, regression losses: 0.11244981599226833, validation losses: 0.5996770293304742
# Epoch 312, reconstruction losses: 0.02660281913208251, regression losses: 0.11791443534869005, validation losses: 0.5082664657953507
# Epoch 313, reconstruction losses: 0.02558374737429656, regression losses: 0.12158341456565053, validation losses: 0.5142682983741955
# Epoch 314, reconstruction losses: 0.03552772929799987, regression losses: 0.19317362221184337, validation losses: 0.4830714246185216
# Epoch 315, reconstruction losses: 0.02947815991340951, regression losses: 0.12829530563224398, validation losses: 0.44835923512103076
# Epoch 316, reconstruction losses: 0.030109766686300575, regression losses: 0.11842529893927836, validation losses: 0.5826918008933994
# Epoch 317, reconstruction losses: 0.026500037127644104, regression losses: 0.12850580802128175, validation losses: 0.6517373775729107
# Epoch 318, reconstruction losses: 0.025783180114036772, regression losses: 0.11731269586562354, validation losses: 0.5774644088435313
# Epoch 319, reconstruction losses: 0.030177502648015365, regression losses: 0.11170825422788147, validation losses: 0.5117735826984701
# Epoch 320, reconstruction losses: 0.025868580739755023, regression losses: 0.09716709243159169, validation losses: 0.48138235746046876
# Epoch 321, reconstruction losses: 0.028827759023522293, regression losses: 0.14175817633405452, validation losses: 0.5416034403777746
# Epoch 322, reconstruction losses: 0.02659815040349475, regression losses: 0.11429317098203234, validation losses: 0.5191688714658886
# Epoch 323, reconstruction losses: 0.026805490286408152, regression losses: 0.11072459446406974, validation losses: 0.44966450797315893
# Epoch 324, reconstruction losses: 0.027598350641963743, regression losses: 0.1145966028675908, validation losses: 0.7183233559535309
# Epoch 325, reconstruction losses: 0.032640171129613635, regression losses: 0.17441728004195683, validation losses: 0.825669416320227
# Epoch 326, reconstruction losses: 0.02774518138978265, regression losses: 0.1386924484286061, validation losses: 0.5241054179418241
# Epoch 327, reconstruction losses: 0.03144036614998714, regression losses: 0.16104430288299323, validation losses: 0.5817699728948018
# Epoch 328, reconstruction losses: 0.030293722295516072, regression losses: 0.13355292593847973, validation losses: 0.4800781575238077
# Epoch 329, reconstruction losses: 0.027145921897113366, regression losses: 0.126293197384752, validation losses: 0.43467208790229656
# Epoch 330, reconstruction losses: 0.027405172991774737, regression losses: 0.11595128439210674, validation losses: 0.47341159469116767
# Epoch 331, reconstruction losses: 0.026170702838099972, regression losses: 0.15002010698082371, validation losses: 0.5659318535434964
# Epoch 332, reconstruction losses: 0.025647243418128046, regression losses: 0.1359980997465307, validation losses: 0.408190461150943
# Epoch 333, reconstruction losses: 0.024169811814202958, regression losses: 0.12958153180255766, validation losses: 0.5072741516028305
# Epoch 334, reconstruction losses: 0.024878439688901077, regression losses: 0.18665856313655832, validation losses: 0.4766295358976883
# Epoch 335, reconstruction losses: 0.025982552311220417, regression losses: 0.19796267228201142, validation losses: 0.6934265966900953
# Epoch 336, reconstruction losses: 0.025972298560045896, regression losses: 0.18136277124835348, validation losses: 0.7761605397961813
# Epoch 337, reconstruction losses: 0.029087279307830137, regression losses: 0.2482563625111876, validation losses: 0.43601602672157247
# Epoch 338, reconstruction losses: 0.027163547742698513, regression losses: 0.16099903762481088, validation losses: 0.8496996401927397
# Epoch 339, reconstruction losses: 0.027634974159110075, regression losses: 0.3793806533371797, validation losses: 0.8959611210508892
# Epoch 340, reconstruction losses: 0.026363164640433003, regression losses: 0.2377817463359607, validation losses: 1.1725783998172996
# Epoch 341, reconstruction losses: 0.02280003609243409, regression losses: 0.1709129988269162, validation losses: 1.0417693872201312
# Epoch 342, reconstruction losses: 0.02367744944410964, regression losses: 0.13601016589610695, validation losses: 0.47668843612846634
# Epoch 343, reconstruction losses: 0.027694433482674315, regression losses: 0.11868114083713567, validation losses: 0.6079281980847526
# Epoch 344, reconstruction losses: 0.024031147034253315, regression losses: 0.12382795378602407, validation losses: 0.5444951059958292
# Epoch 345, reconstruction losses: 0.021457429977623056, regression losses: 0.11493889054051426, validation losses: 0.5073067898764195
# Epoch 346, reconstruction losses: 0.021474383328437104, regression losses: 0.1009184956643153, validation losses: 0.5014770929776794
# Epoch 347, reconstruction losses: 0.024065115917988614, regression losses: 0.12041038696881569, validation losses: 0.4924618799712653
# Epoch 348, reconstruction losses: 0.025412777821675784, regression losses: 0.11659032428084817, validation losses: 0.5166818909649727
# Epoch 349, reconstruction losses: 0.022087964934278767, regression losses: 0.1144269912258103, validation losses: 0.47692027367381157
# Epoch 350, reconstruction losses: 0.02386308202654886, regression losses: 0.12107730384338335, validation losses: 0.46221339558700775
# Epoch 351, reconstruction losses: 0.02149504903477612, regression losses: 0.11385791783794416, validation losses: 0.45277884619548203
# Epoch 352, reconstruction losses: 0.025116058120725593, regression losses: 0.11927132124537126, validation losses: 0.501998182535384
# Epoch 353, reconstruction losses: 0.021463271858826596, regression losses: 0.14572081317812877, validation losses: 0.48359819430251516
# Epoch 354, reconstruction losses: 0.020710420228823013, regression losses: 0.14610058811129495, validation losses: 0.4756499797453154
# Epoch 355, reconstruction losses: 0.02212220744669497, regression losses: 0.1597425436224645, validation losses: 0.521159527891406
# Epoch 356, reconstruction losses: 0.028096742036244557, regression losses: 0.1359803140978589, validation losses: 0.5416630535866519
# Epoch 357, reconstruction losses: 0.022257554094829594, regression losses: 0.12822828273265716, validation losses: 0.4244834748204177
# Epoch 358, reconstruction losses: 0.02304656496943673, regression losses: 0.10462181489575355, validation losses: 0.5423223478977633
# Epoch 359, reconstruction losses: 0.022661811079776863, regression losses: 0.15277754040357297, validation losses: 0.559206150091832
# Epoch 360, reconstruction losses: 0.024708062991665874, regression losses: 0.14353365199463447, validation losses: 0.5266715292505122
# Epoch 361, reconstruction losses: 0.02247209266879866, regression losses: 0.11919966899882435, validation losses: 0.5385718626481684
# Epoch 362, reconstruction losses: 0.022826653401412506, regression losses: 0.12879381036783516, validation losses: 0.6307744239871803
# ...
# Epoch 9882, reconstruction losses: 0.009689270792898495, regression losses: 0.07348812433876717, validation losses: 0.2971672903856071
# Epoch 9883, reconstruction losses: 0.010246271205541772, regression losses: 0.05544187466304014, validation losses: 0.30666198933458233
# Epoch 9884, reconstruction losses: 0.010069193048023561, regression losses: 0.0903867198187399, validation losses: 0.3026668420986839
# Epoch 9885, reconstruction losses: 0.011288001615703262, regression losses: 0.0866868654645042, validation losses: 0.284294596824589
# Epoch 9886, reconstruction losses: 0.01093697899743313, regression losses: 0.10708160427624852, validation losses: 0.275981621087111
# Epoch 9887, reconstruction losses: 0.011885316841825052, regression losses: 0.06918994324313041, validation losses: 0.2751381793429013
# Epoch 9888, reconstruction losses: 0.009554296500863048, regression losses: 0.09281856320328175, validation losses: 0.2690008327243582
# Epoch 9889, reconstruction losses: 0.00973216407898349, regression losses: 0.10491490386097398, validation losses: 0.2668883308598371
# Epoch 9890, reconstruction losses: 0.010858122995744715, regression losses: 0.13201746365747544, validation losses: 0.27700857244455296
# Epoch 9891, reconstruction losses: 0.009942985612684507, regression losses: 0.0939755684252035, validation losses: 0.27774590166471613
# Epoch 9892, reconstruction losses: 0.01017418351728535, regression losses: 0.12011858920979195, validation losses: 0.29809017277201133
# Epoch 9893, reconstruction losses: 0.018608563377702107, regression losses: 0.11541610824231802, validation losses: 0.3040540212421328
# Epoch 9894, reconstruction losses: 0.009985020396605196, regression losses: 0.10004859153727363, validation losses: 0.3012889042978832
# Epoch 9895, reconstruction losses: 0.009996560272866842, regression losses: 0.05539291221554482, validation losses: 0.2930205125904947
# Epoch 9896, reconstruction losses: 0.010124479734324688, regression losses: 0.05614488734048852, validation losses: 0.28085760548383715
# Epoch 9897, reconstruction losses: 0.01098451564001132, regression losses: 0.1882021927757569, validation losses: 0.2749114834964665
# Epoch 9898, reconstruction losses: 0.009564208919397304, regression losses: 0.11831426910535081, validation losses: 0.3117832012975864
# Epoch 9899, reconstruction losses: 0.0154551886583245, regression losses: 0.12814422837137845, validation losses: 0.34638718417007686
# Epoch 9900, reconstruction losses: 0.010623439003670437, regression losses: 0.1187699749758919, validation losses: 0.321942853216514
# Epoch 9901, reconstruction losses: 0.011911842013490118, regression losses: 0.05506302684723447, validation losses: 0.30459590155978594
# Epoch 9902, reconstruction losses: 0.009685165420808522, regression losses: 0.0832709952804466, validation losses: 0.29712966153028914
# Epoch 9903, reconstruction losses: 0.009922109420002006, regression losses: 0.07192494876935897, validation losses: 0.2897121927841109
# Epoch 9904, reconstruction losses: 0.011312008447915724, regression losses: 0.07281659195648855, validation losses: 0.2859186421657695
# Epoch 9905, reconstruction losses: 0.012382245742902979, regression losses: 0.08530846984524006, validation losses: 0.2813112522433042
# Epoch 9906, reconstruction losses: 0.009651153333915658, regression losses: 0.08969298364992515, validation losses: 0.27821166255186885
# Epoch 9907, reconstruction losses: 0.011038392682766412, regression losses: 0.08258827602991359, validation losses: 0.28764214844443026
# Epoch 9908, reconstruction losses: 0.008959900420781394, regression losses: 0.08109822940398125, validation losses: 0.291923159128477
# Epoch 9909, reconstruction losses: 0.009607223215271419, regression losses: 0.07563021509613803, validation losses: 0.2843498415891924
# Epoch 9910, reconstruction losses: 0.010401992395811023, regression losses: 0.06861325296936778, validation losses: 0.29992142898410185
# Epoch 9911, reconstruction losses: 0.010590318598106663, regression losses: 0.08648717844015191, validation losses: 0.2944065737304758
# Epoch 9912, reconstruction losses: 0.011297421454307987, regression losses: 0.08109501350493178, validation losses: 0.2904746428267466
# Epoch 9913, reconstruction losses: 0.008251262684805229, regression losses: 0.10038333052386439, validation losses: 0.2755181422610349
# Epoch 9914, reconstruction losses: 0.013410938424441816, regression losses: 0.09537171013440185, validation losses: 0.28288350853489785
# Epoch 9915, reconstruction losses: 0.010077912912605302, regression losses: 0.10127556712997628, validation losses: 0.3047145839686216
# Epoch 9916, reconstruction losses: 0.012308119984282516, regression losses: 0.06585498848233692, validation losses: 0.2757370536570643
# Epoch 9917, reconstruction losses: 0.009125788537436676, regression losses: 0.07703753616737229, validation losses: 0.2709904214226751
# Epoch 9918, reconstruction losses: 0.009291152823191644, regression losses: 0.07572963834014651, validation losses: 0.2682916268817235
# Epoch 9919, reconstruction losses: 0.010803149464117515, regression losses: 0.08225969299146375, validation losses: 0.2685979738650273
# Epoch 9920, reconstruction losses: 0.01569934279575327, regression losses: 0.12087591876649952, validation losses: 0.26670644560428775
# Epoch 9921, reconstruction losses: 0.010125548149028782, regression losses: 0.06275177509156134, validation losses: 0.26858594469046293
# Epoch 9922, reconstruction losses: 0.012486685311912032, regression losses: 0.10533921968921978, validation losses: 0.26779105921380164
# Epoch 9923, reconstruction losses: 0.009375675591138864, regression losses: 0.05085873369403549, validation losses: 0.2681044570701087
# Epoch 9924, reconstruction losses: 0.0099555865261844, regression losses: 0.07792397210520509, validation losses: 0.2762028766464302
# Epoch 9925, reconstruction losses: 0.012326469284654577, regression losses: 0.12103310041171615, validation losses: 0.2988931556605472
# Epoch 9926, reconstruction losses: 0.00958778546739892, regression losses: 0.06525342491658709, validation losses: 0.35606631718130616
# Epoch 9927, reconstruction losses: 0.009774337943745126, regression losses: 0.08458238977873389, validation losses: 0.3566005834330367
# Epoch 9928, reconstruction losses: 0.009565102855919548, regression losses: 0.0782469306733151, validation losses: 0.3130274843091187
# Epoch 9929, reconstruction losses: 0.00933180883199938, regression losses: 0.08954227485393564, validation losses: 0.3109049194874056
# Epoch 9930, reconstruction losses: 0.011370456664123972, regression losses: 0.11020864745168911, validation losses: 0.2995244929049617
# Epoch 9931, reconstruction losses: 0.009500102313690134, regression losses: 0.08109740820479845, validation losses: 0.2903106940204401
# Epoch 9932, reconstruction losses: 0.013453288982335032, regression losses: 0.11482579900967195, validation losses: 0.2929528143561706
# Epoch 9933, reconstruction losses: 0.01334694023328043, regression losses: 0.15915050615064613, validation losses: 0.2852548803106442
# Epoch 9934, reconstruction losses: 0.009483256696757484, regression losses: 0.06158022354003227, validation losses: 0.27749343578722535
# Epoch 9935, reconstruction losses: 0.008269367557543834, regression losses: 0.06635716242487433, validation losses: 0.27022767215832416
# Epoch 9936, reconstruction losses: 0.01387083943761821, regression losses: 0.06739727758736547, validation losses: 0.26822924942690224
# Epoch 9937, reconstruction losses: 0.009193555739792482, regression losses: 0.0707526108329812, validation losses: 0.28291191526596077
# Epoch 9938, reconstruction losses: 0.010013393261015002, regression losses: 0.0776351335413315, validation losses: 0.27878854312692486
# Epoch 9939, reconstruction losses: 0.009918059597230026, regression losses: 0.08407140161492963, validation losses: 0.2705977897821361
# Epoch 9940, reconstruction losses: 0.010129886615918477, regression losses: 0.10302909982292424, validation losses: 0.26857469151849434
# Epoch 9941, reconstruction losses: 0.00920664157359199, regression losses: 0.07134740561611244, validation losses: 0.2674889490915702
# Epoch 9942, reconstruction losses: 0.009174713491602973, regression losses: 0.08717414220337073, validation losses: 0.2660816146852567
# Epoch 9943, reconstruction losses: 0.01130012218945931, regression losses: 0.07656464400322452, validation losses: 0.26507462946842086
# Epoch 9944, reconstruction losses: 0.01131028457513447, regression losses: 0.08419076466472364, validation losses: 0.27110025760307904
# Epoch 9945, reconstruction losses: 0.010245197185983879, regression losses: 0.09361569066537444, validation losses: 0.2882400901731459
# Epoch 9946, reconstruction losses: 0.010198320321673244, regression losses: 0.09402030492413216, validation losses: 0.2864036721497416
# Epoch 9947, reconstruction losses: 0.00879235607714713, regression losses: 0.09020156618235235, validation losses: 0.2873997243853407
# Epoch 9948, reconstruction losses: 0.009170419743356995, regression losses: 0.08474176828337751, validation losses: 0.3036761464774628
# Epoch 9949, reconstruction losses: 0.009793323287937857, regression losses: 0.14750144890607272, validation losses: 0.34933417634076713
# Epoch 9950, reconstruction losses: 0.014068744128209423, regression losses: 0.11396113678649082, validation losses: 0.35584444083003575
# Epoch 9951, reconstruction losses: 0.012337914183452908, regression losses: 0.09230734404753184, validation losses: 0.29835646721203507
# Epoch 9952, reconstruction losses: 0.010268034588572455, regression losses: 0.07973553468257247, validation losses: 0.2797603450298774
# Epoch 9953, reconstruction losses: 0.00878799135602408, regression losses: 0.07421611991645369, validation losses: 0.2951239405788968
# Epoch 9954, reconstruction losses: 0.00898856695939212, regression losses: 0.06860785660894922, validation losses: 0.2881620197806797
# Epoch 9955, reconstruction losses: 0.012769526867290094, regression losses: 0.11743418519182384, validation losses: 0.2701475190835954
# Epoch 9956, reconstruction losses: 0.009859026432143368, regression losses: 0.07898838144875123, validation losses: 0.2884595791820618
# Epoch 9957, reconstruction losses: 0.011688657456249077, regression losses: 0.08812131639800219, validation losses: 0.3118846914208803
# Epoch 9958, reconstruction losses: 0.009622755883113527, regression losses: 0.06925613726420671, validation losses: 0.2752334898168931
# Epoch 9959, reconstruction losses: 0.008536688208979338, regression losses: 0.05725028581400289, validation losses: 0.26488705716419353
# Epoch 9960, reconstruction losses: 0.014388789207231046, regression losses: 0.15050063901504593, validation losses: 0.2790913163558528
# Epoch 9961, reconstruction losses: 0.010939461369893337, regression losses: 0.126922552160463, validation losses: 0.3161606838493757
# Epoch 9962, reconstruction losses: 0.011442759131278533, regression losses: 0.0697915839929232, validation losses: 0.28513941352086214
# Epoch 9963, reconstruction losses: 0.01049616956970951, regression losses: 0.09800586604099149, validation losses: 0.2868737175477411
# Epoch 9964, reconstruction losses: 0.01022289682303199, regression losses: 0.07402026440348648, validation losses: 0.3435438735056866
# Epoch 9965, reconstruction losses: 0.016977280812252287, regression losses: 0.17313513918553777, validation losses: 0.3427806582224943
# Epoch 9966, reconstruction losses: 0.010953635311904101, regression losses: 0.11017537983285673, validation losses: 0.3653876738711459
# Epoch 9967, reconstruction losses: 0.010202216681361653, regression losses: 0.08658938699067566, validation losses: 0.3049316065729689
# Epoch 9968, reconstruction losses: 0.010088922924737457, regression losses: 0.08915270226220909, validation losses: 0.2948364144901405
# Epoch 9969, reconstruction losses: 0.008408393610450064, regression losses: 0.06627902361640715, validation losses: 0.2981997942287896
# Epoch 9970, reconstruction losses: 0.011018338870444825, regression losses: 0.07833805644546721, validation losses: 0.29742533212261585
# Epoch 9971, reconstruction losses: 0.010735500482229259, regression losses: 0.10009316871873203, validation losses: 0.29722802492396005
# Epoch 9972, reconstruction losses: 0.008910428637879624, regression losses: 0.06498407887861604, validation losses: 0.285963684045686
# Epoch 9973, reconstruction losses: 0.009540186902864314, regression losses: 0.06766000355731794, validation losses: 0.2777647671623794
# Epoch 9974, reconstruction losses: 0.00818404638381488, regression losses: 0.0558285872312901, validation losses: 0.28147910561228856
# Epoch 9975, reconstruction losses: 0.010237246683177197, regression losses: 0.10451651398840599, validation losses: 0.287664179857396
# Epoch 9976, reconstruction losses: 0.009184068859145042, regression losses: 0.07339426577235902, validation losses: 0.28456980955595335
# Epoch 9977, reconstruction losses: 0.00944379450205453, regression losses: 0.06793793477675676, validation losses: 0.28343771292246633
# Epoch 9978, reconstruction losses: 0.012436853642548474, regression losses: 0.0749485157195001, validation losses: 0.2800510572418019
# Epoch 9979, reconstruction losses: 0.010923284861438912, regression losses: 0.10950878522981672, validation losses: 0.280275313944778
# Epoch 9980, reconstruction losses: 0.009461123539239533, regression losses: 0.07224298306377813, validation losses: 0.2780507044830207
# Epoch 9981, reconstruction losses: 0.010259106564871482, regression losses: 0.06524556583753806, validation losses: 0.287604430016004
# Epoch 9982, reconstruction losses: 0.00979352040511379, regression losses: 0.08398602848127276, validation losses: 0.2787472700774487
# Epoch 9983, reconstruction losses: 0.01016553157951867, regression losses: 0.0825110261678674, validation losses: 0.2800543697595843
# Epoch 9984, reconstruction losses: 0.011444642788914165, regression losses: 0.08385247467605268, validation losses: 0.2832872067963464
# Epoch 9985, reconstruction losses: 0.009383806904957792, regression losses: 0.08129608205059333, validation losses: 0.2783742646087936
# Epoch 9986, reconstruction losses: 0.010528610084041264, regression losses: 0.06871703173030008, validation losses: 0.2744647881224577
# Epoch 9987, reconstruction losses: 0.010507437315775182, regression losses: 0.13960574278316176, validation losses: 0.2645431329117879
# Epoch 9988, reconstruction losses: 0.010996895548444626, regression losses: 0.10911613458436459, validation losses: 0.29826627857614524
# Epoch 9989, reconstruction losses: 0.009837069841009065, regression losses: 0.07671577895548566, validation losses: 0.3448390846196788
# Epoch 9990, reconstruction losses: 0.01028730506571254, regression losses: 0.08222714659624199, validation losses: 0.3084383533932722
# Epoch 9991, reconstruction losses: 0.0100528569629775, regression losses: 0.09112910442491502, validation losses: 0.2902240987095365
# Epoch 9992, reconstruction losses: 0.009839419502682255, regression losses: 0.07492896904007763, validation losses: 0.27501496077357623
# Epoch 9993, reconstruction losses: 0.009603847460706532, regression losses: 0.07818691302950356, validation losses: 0.27911360191552126
# Epoch 9994, reconstruction losses: 0.0085408035473782, regression losses: 0.07871272123647739, validation losses: 0.2850766838894865
# Epoch 9995, reconstruction losses: 0.013884313723806805, regression losses: 0.10905157416005415, validation losses: 0.30726733996701006
# Epoch 9996, reconstruction losses: 0.009164493344061785, regression losses: 0.0654038153699961, validation losses: 0.33397138083050637
# Epoch 9997, reconstruction losses: 0.012302118008921078, regression losses: 0.08479828530306924, validation losses: 0.3426468633627621
# Epoch 9998, reconstruction losses: 0.011848344049043369, regression losses: 0.06670683926016298, validation losses: 0.30965253783832064
# Epoch 9999, reconstruction losses: 0.012498004401496097, regression losses: 0.08120716813007045, validation losses: 0.28533150636842897

# %%
testing_pos, testing_err, rssi_reconst = DSAR_testing(testing_wifi_pos, dataset, boundary)
avg_test_err= sum(testing_err) / len(testing_err)
plot_wifi_pos(dataset, method, training_wifi_pos[:,-2:], testing_wifi_pos[:,-2:], testing_pos, testing_err)

# %%
#listing the difference of original label and predicted label
import cmath
testing_labels = testing_wifi_pos[:, -2:]
for i, label in enumerate(testing_labels):
    err = (label - testing_pos[i])
    err = cmath.sqrt(err[0]**2 + err[-1]**2)
    print(f"original label = {label} -> predicted label = {testing_pos[i]}, err = {err}")
print(f"testing avg error = {avg_test_err}")
# Out:
# original label = [-1. 14.] -> predicted label = [-2.63282204 13.87366143], err = (1.6377024324263367+0j)
# original label = [-1. 20.] -> predicted label = [-1.93389521 19.93969232], err = (0.9358404144815224+0j)
# original label = [-10.  14.] -> predicted label = [-10.55102164  14.33723335], err = (0.646027231974875+0j)
# original label = [-10.  16.] -> predicted label = [-9.79662737 18.23501007], err = (2.244243846446759+0j)
# original label = [-10.  18.] -> predicted label = [-9.35050443 20.25262638], err = (2.3443912010795787+0j)
# original label = [-10.  20.] -> predicted label = [-9.7221715  20.48658881], err = (0.5603189623804234+0j)
# original label = [-10.  22.] -> predicted label = [-9.83993989 20.52615517], err = (1.482510648772756+0j)
# original label = [-11.  14.] -> predicted label = [-12.24527383  14.62719018], err = (1.3943007003050845+0j)
# original label = [-11.  20.] -> predicted label = [-10.25947654  20.30500492], err = (0.8008763870340436+0j)
# original label = [-13.  14.] -> predicted label = [-13.67360574  14.98633226], err = (1.1944019469907652+0j)
# original label = [-13.  20.] -> predicted label = [-13.13407577  20.59455824], err = (0.6094881516775287+0j)
# original label = [-14.  14.] -> predicted label = [-13.8530667   15.36021893], err = (1.3681319181395946+0j)
# original label = [-14.  16.] -> predicted label = [-13.98778465  15.12174427], err = (0.8783406798984752+0j)
# original label = [-14.  18.] -> predicted label = [-13.91670865  20.63422683], err = (2.6355432941195196+0j)
# original label = [-14.  20.] -> predicted label = [-13.97412143  21.08334482], err = (1.0836538691502688+0j)
# original label = [-14.  22.] -> predicted label = [-13.51489003  21.53255007], err = (0.6736773147496082+0j)
# original label = [-15.  14.] -> predicted label = [-15.80177237  14.15574923], err = (0.8167599181620498+0j)
# original label = [-17.  14.] -> predicted label = [-16.65234217  14.13374043], err = (0.37249492878283874+0j)
# original label = [-19.  14.] -> predicted label = [-17.25174084  14.01309587], err = (1.7483082081733232+0j)
# original label = [-3. 14.] -> predicted label = [-3.83302172 13.87892997], err = (0.8417738002500097+0j)
# original label = [-3. 20.] -> predicted label = [-4.96102673 19.94285494], err = (1.9618591682824+0j)
# original label = [-5. 14.] -> predicted label = [-5.12197981 13.94200012], err = (0.1350668705223772+0j)
# original label = [-5. 20.] -> predicted label = [-6.53623821 19.93055393], err = (1.5378070695748274+0j)
# original label = [-7. 14.] -> predicted label = [-6.67727332 13.98979087], err = (0.3228881164306285+0j)
# original label = [-7. 20.] -> predicted label = [-8.29612365 20.12868046], err = (1.3024957530438526+0j)
# original label = [-9. 14.] -> predicted label = [-8.96472319 13.95643156], err = (0.05605945672393927+0j)
# original label = [-9. 20.] -> predicted label = [-9.8617698  20.47459331], err = (0.9838119732344653+0j)
# testing avg error = 1.132176824548439
